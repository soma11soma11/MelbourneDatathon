# %%
import csv
import pandas as pd
import numpy as np

# %%
new_data = pd.read_csv('semi_and_final_features.csv')
new_data
# Out:
#        ﻿Account_ID   EVENT_ID  TRANSACTION_COUNT STATUS_ID INPLAY_BET  \
# 0          1000002  101187238                  6         C          N
# 1          1000002  101187238                  2         S          N
# 2          1000002  101187238                 43         S          Y
# 3          1000002  101187943                  8         C          N
# 4          1000002  101187943                 69         S          Y
# 5          1000002  101191295                  2         S          N
# 6          1000002  101191295                 11         S          Y
# 7          1000003  101187238                  1         S          N
# 8          1000003  101187943                  1         S          N
# 9          1000004  101187943                  1         S          N
# 10         1000005  101187238                  1         L          N
# 11         1000005  101187238                  7         S          Y
# ...

# %%
old_data1 = pd.read_csv('Datathon Full Dataset/Datathon WC Data Games 1-10.csv')
old_data2 = pd.read_csv('Datathon Full Dataset/Datathon WC Data Games 11-20.csv')
old_data3 = pd.read_csv('Datathon Full Dataset/Datathon WC Data Games 21-30.csv')
old_data4 = pd.read_csv('Datathon Full Dataset/Datathon WC Data Games 31-40.csv')
old_data5 = pd.read_csv('Datathon Full Dataset/Datathon WC Data Games QTR Finals.csv')
# Out:
# /Users/Soma/.pyenv/versions/3.5.0/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/Soma/.pyenv/versions/3.5.0/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
old_data1
# Out:
#          ﻿"BET_ID"  BET_TRANS_ID  MATCH_BET_ID  ACCOUNT_ID  \
# 0       4755948997    5899638727    4755952732     1009306
# 1       4755948997    5899639259    4755953131     1009306
# 2       4755948997    5899635908    4755950405     1009306
# 3       4755948997    5899637522    4755951701     1009306
# 4       4755948997    5899637711    4755951932     1009306
# 5       4755948997    5899634081    4755949123     1009306
# 6       4755948997    5899634536    4755949510     1009306
# 7       4755948997    5899635844    4755950354     1009306
# 8       4755948997    5899637814    4755952020     1009306
# 9       4755948997    5899637597    4755951796     1009306
# 10      4755948997    5899634265    4755949241     1009306
# 11      4755948997    5899635819    4755950334     1009306
# 12      4753994561    5897331919    4753990382     1005119
# 13      4753228551    5896452741    4753227067     1018472
# 14      4753228693    5896452961    4753227280     1018472
# ...

# %%
old_data1['BET_ID']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-24ec4855b490> in <module>()
# ----> 1 old_data1['BET_ID']
#
# /Users/Soma/.pyenv/versions/3.5.0/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1912             return self._getitem_multilevel(key)
#    1913         else:
# -> 1914             return self._getitem_column(key)
#    1915
#    1916     def _getitem_column(self, key):
#
# /Users/Soma/.pyenv/versions/3.5.0/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1919         # get column
#    1920         if self.columns.is_unique:
# -> 1921             return self._get_item_cache(key)
#    1922
#    1923         # duplicate columns & possible reduce dimensionaility
#
# /Users/Soma/.pyenv/versions/3.5.0/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
# ...
